# %% [markdown]
# ## Buatlah sebuah program yang:
#
#    1. Meminta input dari pengguna:
#
#        - Nama mahasiswa
#
#        - NIM mahasiswa
#
#        - Nilai ujian (dalam angka, 0–100)
#
#    2. Cek dan tampilkan tipe data dari setiap input.
#
#    3. Gunakan if-elif-else untuk menentukan kategori nilai, dengan kriteria sebagai berikut:
#
# ```
# Nilai | Kategori
# 85 - 100 | A (Sangat Baik)
# 75 - 84 | B (Baik)
# 60 - 74 | C (Cukup)
# 40 - 59 | D (Kurang)
# < 40 | E (Sangat Kurang)
# ```
#
# ```
# ==== Ekspektasi Output Jawaban : =====
# Masukkan nama mahasiswa: Sarah
# Masukkan NIM: 12345678
# Masukkan nilai ujian (0-100): 81
#
# Nama: Sarah (type: <class 'str'>)
# NIM: 12345678 (type: <class 'str'>)
# Nilai: 81 (type: <class 'int'>)
#
# Hasil Evaluasi:
# Mahasiswa: Sarah (NIM: 12345678)
# Nilai Ujian: 81
# Kategori Nilai: B (Baik)
# ```

# %%
# Meminta input dari pengguna
nama = input("Masukkan nama mahasiswa: ")
nim = input("Masukkan NIM mahasiswa: ")
nilai_input = input("Masukkan nilai ujian (0–100): ")

# Menampilkan tipe data dari setiap input sebelum konversi
print("\nTipe data sebelum konversi:")
print("Nama:", type(nama))
print("NIM:", type(nim))
print("Nilai (sebelum dikonversi):", type(nilai_input))

# Konversi nilai ujian ke tipe data integer
try:
    nilai = int(nilai_input)

    # Menampilkan tipe data setelah konversi
    print("\nTipe data setelah konversi:")
    print("Nilai:", type(nilai))

    # Menentukan kategori nilai
    if 85 <= nilai <= 100:
        kategori = "A (Sangat Baik)"
    elif 75 <= nilai <= 84:
        kategori = "B (Baik)"
    elif 60 <= nilai <= 74:
        kategori = "C (Cukup)"
    elif 40 <= nilai <= 59:
        kategori = "D (Kurang)"
    elif 0 <= nilai < 40:
        kategori = "E (Sangat Kurang)"
    else:
        kategori = "Nilai di luar rentang yang valid."

    # Menampilkan hasil
    print("\nHasil:")
    print("Nama Mahasiswa:", nama, "("nim")")
    print("Nilai Ujian:", nilai)
    print("Kategori Nilai:", kategori)

except ValueError:
    print("\nError: Nilai ujian harus berupa angka antara 0 sampai 100.")
# Out:
# Masukkan nama mahasiswa: sarah
# Masukkan NIM mahasiswa: 4378873489
# Masukkan nilai ujian (0–100): 69
#
# Tipe data sebelum konversi:
# Nama: <class 'str'>
# NIM: <class 'str'>
# Nilai (sebelum dikonversi): <class 'str'>
#
# Tipe data setelah konversi:
# Nilai: <class 'int'>
#
# Hasil:
# Nama Mahasiswa: sarah 4378873489
# Nilai Ujian: 69
# Kategori Nilai: C (Cukup)
